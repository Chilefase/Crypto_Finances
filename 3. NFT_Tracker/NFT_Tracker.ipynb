# %%
# First, let's load a few useful packages
library(knitr)
library(tidyverse)
library(httr)
library(jsonlite)
library(plotly)
library(patchwork)
library(cowplot)
library(network)
library(ggraph)
library(networkDynamic)
library(ndtv)
library(tsna)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-21aff5acf61f> in <module>()
#       1 # First, let's load a few useful packages
# ----> 2 library(knitr)
#       3 library(tidyverse)
#       4 library(httr)
#       5 library(jsonlite)
#
# NameError: name 'library' is not defined
